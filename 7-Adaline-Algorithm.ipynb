# %%
import numpy as np

# %%
X = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])

# Target Output for AND gate
y = np.array([0, 0, 0, 1])

print("Input Dataset:")
for i in range(len(X)):
    print(f"Input: {X[i]} --> Output: {y[i]}")
# Out:
# Input Dataset:
# Input: [0 0] --> Output: 0
# Input: [0 1] --> Output: 0
# Input: [1 0] --> Output: 0
# Input: [1 1] --> Output: 1

# %%
np.random.seed(42)
weights = np.random.randn(2) * 0.01
bias = 0.0

learning_rate = 0.1
epochs = 50

print("\nInitial Weights:", weights)
print("Initial Bias:", bias)
# Out:
# Initial Weights: [ 0.00496714 -0.00138264]
# Initial Bias: 0.0

# %%
def activation_function(x):
    return 1 if x >= 0.5 else 0

# %%
for epoch in range(epochs):
    total_error = 0

    for i in range(len(X)):
        # Net Input (Linear Output)
        net_input = np.dot(X[i], weights) + bias

        # Error Calculation
        error = y[i] - net_input
        total_error += error ** 2

        # Weight Update Rule (Adaline / Delta Rule)
        weights = weights + learning_rate * error * X[i]
        bias = bias + learning_rate * error

    # Print progress every 5 epochs
    if (epoch + 1) % 5 == 0:
        print(f"Epoch {epoch+1}, Mean Squared Error: {total_error:.4f}")
# Out:
# Epoch 5, Mean Squared Error: 0.5332
# Epoch 10, Mean Squared Error: 0.4226
# Epoch 15, Mean Squared Error: 0.3644
# Epoch 20, Mean Squared Error: 0.3355
# Epoch 25, Mean Squared Error: 0.3213
# Epoch 30, Mean Squared Error: 0.3144
# Epoch 35, Mean Squared Error: 0.3111
# Epoch 40, Mean Squared Error: 0.3096
# Epoch 45, Mean Squared Error: 0.3089
# Epoch 50, Mean Squared Error: 0.3086

# %%
print("\nTraining Completed")
print("Final Weights:", weights)
print("Final Bias:", bias)
# Out:
# Training Completed
# Final Weights: [0.54280919 0.51451564]
# Final Bias: -0.2602214456806771

# %%
print("\nFinal Predictions after Training:")

correct = 0

for i in range(len(X)):
    net_input = np.dot(X[i], weights) + bias
    prediction = activation_function(net_input)

    print(f"Input: {X[i]} --> Actual: {y[i]}, Predicted: {prediction}")

    if prediction == y[i]:
        correct += 1
# Out:
# Final Predictions after Training:
# Input: [0 0] --> Actual: 0, Predicted: 0
# Input: [0 1] --> Actual: 0, Predicted: 0
# Input: [1 0] --> Actual: 0, Predicted: 0
# Input: [1 1] --> Actual: 1, Predicted: 1

# %%
accuracy = (correct / len(X)) * 100
print(f"\nAccuracy: {accuracy:.2f}%")
# Out:
# Accuracy: 100.00%
